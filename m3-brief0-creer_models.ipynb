# %% [markdown]
# # Import des données.
#
# La base de données est fabriqué à partir d'un dataset au préalable traité via une reconstruction de données effectué dans le module 3.
#
# Ce dataset se trouve dans le fichier CSV `data/00-reconstructed-dataset.csv'
#
# **NOTA : Ce code étant du code jetable peu de soin seront fait sur le controle d'erreur.**

# %%
from select import select

# Bootstrap
import pandas as pd

# %%
from sqlalchemy import create_engine, select, func, delete, update
import sqlalchemy as sa
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy import Column, Integer, String, Float, Date, ForeignKey

# %% [markdown]
# ## Construction du model
#
# ### Recupération de la structure du fichier

# %%
df = pd.read_csv('data/00-reconstructed-dataset.csv')
# Conversion de la date_creation_compte en vrai date
df['date_creation_compte'] = pd.to_datetime(df['date_creation_compte']).dt.date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4707 entries, 0 to 4706
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nom                    4707 non-null   object
#  1   prenom                 4707 non-null   object
#  2   age                    4707 non-null   int64
#  3   taille                 4707 non-null   float64
#  4   poids                  4707 non-null   float64
#  5   sexe                   4707 non-null   object
#  6   sport_licence          4707 non-null   object
#  7   niveau_etude           4707 non-null   object
#  8   region                 4707 non-null   object
#  9   smoker                 4707 non-null   object
#  10  nationalite_francaise  4707 non-null   object
#  11  revenu_estime_mois     4707 non-null   float64
#  12  situation_familiale    4707 non-null   object
#  13  historique_credits     4707 non-null   float64
#  14  risque_personnel       4707 non-null   float64
#  15  date_creation_compte   4707 non-null   object
#  16  score_credit           4707 non-null   float64
#  17  loyer_mensuel          4707 non-null   float64
#  18  montant_pret           4707 non-null   float64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 698.8+ KB

# %% [markdown]
# ## Creation de la base from scratch

# %%
DATABASE_FILE = 'data/database.db'
DATABASE_URI = f'sqlite:///./{DATABASE_FILE}'

Base = declarative_base()

# Suppression de la base

# %%
# Models
class Raw_data(Base):
    __tablename__ = "raw_data"

    # Clé primaire auto-incrémentée (bonne pratique)
    id = Column(Integer, primary_key=True, index=True)

    # Colonnes mappées depuis le DataFrame
    nom = Column(String)
    prenom = Column(String)
    age = Column(Integer)
    taille = Column(Float)
    poids = Column(Float)
    sexe = Column(String)
    sport_licence = Column(String)
    niveau_etude = Column(String)
    region = Column(String)
    smoker = Column(String) # voir a mettre un bool car oui/non
    nationalite_francaise = Column(String) # voir a mettre un bool car oui/non
    revenu_estime_mois = Column(Float)
    situation_familiale = Column(String)
    historique_credits = Column(Float)
    risque_personnel = Column(Float)
    date_creation_compte = Column(Date)
    score_credit = Column(Float)
    loyer_mensuel = Column(Float)
    montant_pret = Column(Float)

# %% [markdown]
# ## Création des models spécialisé

# %%
# Model Pret
# Ca correspond à chaque ligne du dataset, dans le dataset, ca correspond à un contrat par ligne

class Pret(Base):
    __tablename__ = "pret"

    # Clé primaire auto-incrémentée (numero de pret)
    num_pret = Column(Integer, primary_key=True, index=True)

    age = Column(Integer)
    taille = Column(Float)
    poids = Column(Float)
    sport_licence = Column(String)
    region = Column(String)
    smoker = Column(String) # voir a mettre un bool car oui/non
    revenu_estime_mois = Column(Float)
    situation_familiale = Column(String)
    historique_credits = Column(Float)
    risque_personnel = Column(Float)
    date_creation_compte = Column(Date)
    score_credit = Column(Float)
    loyer_mensuel = Column(Float)
    montant_pret = Column(Float)

    # Clé étrangère
    # Client
    client_id = Column(Integer, ForeignKey('client.id'))
    client = relationship("Client", back_populates="prets")

    # Region
    region_id = Column(Integer, ForeignKey('region.id'))
    region = relationship("Region", back_populates="prets")

    # Niveau d'étude
    niveau_etude_id = Column(Integer, ForeignKey('niveau_etude.id'))
    niveau_etude = relationship("Niveau_etude", back_populates="prets")

# %%
# Model client
class Client(Base):
    __tablename__ = "client"

    # Clé primaire auto-incrémentée (bonne pratique)
    id = Column(Integer, primary_key=True, index=True)

    # Colonnes mappées depuis le DataFrame
    nom = Column(String)
    prenom = Column(String)
    sexe = Column(String)
    nationalite_francaise = Column(String) # voir a mettre un bool car oui/non

    # Relations
    prets = relationship("Pret", back_populates="client")

    def __repr__(self):
        """Méthode qui renvoie une représentation sous forme de chaîne de caractères du client.

        La chaîne contient l'identifiant, le nom et le prénom du client.

        Returns :
            str : Une chaîne formatée avec l'ID, le nom et le prénom du client.
        """
        return f"<Client N°{self.id} ; {self.nom} {self.prenom}>"

# %%
# Dictionnaires
class Region(Base):
    __tablename__ = "region"

    id = Column(Integer, primary_key=True, index=True)
    nom = Column(String)

    # Relations
    prets = relationship("Pret", back_populates="region")

class Niveau_etude(Base):
    __tablename__ = "niveau_etude"

    id = Column(Integer, primary_key=True, index=True)
    nom = Column(String)

    # Relations
    prets = relationship("Pret", back_populates="niveau_etude")

# %% [markdown]
# ## Création de la base

# %%
# Creation de la base vide
engine = create_engine(DATABASE_URI)

# A voir si ca recrer les tables ou si ca zap ce qui existe deja.
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Populate de la base
#
# **/!\\ Les cellules on un flag `populate_*` pour executer ou non les opération de remplissage des tables. Ca permet de relancer le notebook depuis le debut sans recréer les données déjà dans la base /!\\**

# %%
populate_raw = False
populate_client = False
populate_dico = False
populate_pret = False

# %%
# Remplissage brute avec les données du dataset
if populate_raw:
    for line in df.itertuples(index=False):
        dictline = line._asdict()
        new_raw_data = Raw_data(**dictline)
        session.add(new_raw_data)
        session.commit()

# %% [markdown]
# ### Analyse des clients
#
# On va remplir la base des client en les regroupant par nom, prenom, sexe et nationalite_française, c'est un choix arbitraire pour créer des clients multi possesseur de prêt.

# %%
# Construction de la requete

stm_client_groupe_t = select(
        # Raw_data,
        Raw_data.nom,
        Raw_data.prenom,
        Raw_data.nationalite_francaise,
        Raw_data.sexe
    ).group_by(  # GROUP BY ...
        Raw_data.nom,
        Raw_data.prenom,
        Raw_data.nationalite_francaise,
        Raw_data.sexe
    )

print(stm_client_groupe_t)
# TODO : Déterminé s'il est possible de récupérer que quelques colonne tout en conservant l'instance de Raw_data.
# Vu les soucis pour obtenir des instances de Raw_data avec un select sur un sous ensemble de colonne on prend toutes les colonnes, le soucis est peut-être lié a la mecanique de SQLAlchemy qui necessite un record complet pour retourner une instance

stm_client_groupe = select(Raw_data).group_by(  # GROUP BY ...
        Raw_data.nom,
        Raw_data.prenom,
        Raw_data.nationalite_francaise,
        Raw_data.sexe
    )

# execution de la requete

liste_client = session.scalars(stm_client_groupe).all()
# On test la requetes SQL direct
print(session.execute(sa.text("SELECT * FROM raw_data GROUP BY nom, prenom, sexe, nationalite_francaise LIMIT 10")).all())

# Populate de la table
if populate_client:
    for ligne in liste_client:
        print(vars(ligne))
        new_client = Client(**{
            'nom': ligne.nom,
            'prenom': ligne.prenom,
            'sexe': ligne.sexe,
            'nationalite_francaise': ligne.nationalite_francaise,
        })
        session.add(new_client)
    session.commit()

# On peux populate directement avec
# INSERT INTO client (nom, prenom, sexe, nationalite_francaise) SELECT nom, prenom, sexe, nationalite_francaise FROM raw_data GROUP BY nom, prenom, sexe, nationalite_francaise
# On se force à utiliser l'ORM, il apparait que cette approche est bien plus lente
# Out:
# SELECT raw_data.nom, raw_data.prenom, raw_data.nationalite_francaise, raw_data.sexe
# FROM raw_data GROUP BY raw_data.nom, raw_data.prenom, raw_data.nationalite_francaise, raw_data.sexe
# [(272, 'Abbott', 'Adam', 74, 165.2, 57.1, 'F', 'oui', 'doctorat', 'Hauts-de-France', 'oui', 'oui', 2270.0, 'veuf', 4.0, 0.92, '2021-12-07', 576.0, 1220.4, 9981.382567383063), (1424, 'Acevedo', 'Pamela', 67, 176.1, 66.5, 'F', 'oui', 'master', 'Bretagne', 'non', 'oui', 2141.0, 'veuf', 3.0, 0.62, '2024-12-19', 581.0, 913.2, 25261.091226700035), (2678, 'Acosta', 'Douglas', 71, 166.6, 73.6, 'H', 'oui', 'doctorat', 'Corse', 'non', 'oui', 1579.0, 'divorcé', 4.0, 0.81, '2024-07-30', 576.0, 836.5600000000001, 17478.508978244045), (553, 'Acosta', 'Sarah', 59, 154.3, 80.3, 'H', 'oui', 'aucun', 'Île-de-France', 'oui', 'non', 864.0, 'veuf', 5.0, 0.76, '2021-12-01', 828.0, 270.52, 500.0), (3966, 'Adams', 'Amy', 56, 177.9, 63.9, 'H', 'oui', 'bac+2', 'Île-de-France', 'non', 'oui', 2988.0, 'divorcé', 5.0, 0.29, '2021-05-16', 608.0, 626.27, 31915.41316127932), (2834, 'Adams', 'Brandi', 24, 186.3, 62.2, 'H', 'non', 'bac+2', 'Auvergne-Rhône-Alpes', 'non', 'oui', 5028.0, 'célibataire', 5.0, 0.91, '2021-06-10', 654.0, 1001.3679999999998, 38753.47407594087), (483, 'Adams', 'Casey', 53, 162.3, 95.4, 'H', 'oui', 'bac', 'Normandie', 'oui', 'oui', 2849.0, 'marié', 3.0, 0.12, '2024-07-06', 387.0, 703.33, 500.0), (585, 'Adams', 'Daniel', 44, 170.9, 64.8, 'F', 'oui', 'master', 'Île-de-France', 'non', 'oui', 1872.0, 'divorcé', 2.0, 0.33, '2024-07-18', 321.0, 641.9459999999999, 25731.459876239493), (1789, 'Adams', 'Denise', 23, 171.8, 53.9, 'F', 'oui', 'master', 'Provence-Alpes-Côte d’Azur', 'non', 'oui', 4908.0, 'veuf', 3.0, 0.21, '2020-09-16', 581.0, 800.142, 29082.318084504), (1130, 'Adams', 'Elizabeth', 75, 171.6, 85.3, 'F', 'oui', 'doctorat', 'Provence-Alpes-Côte d’Azur', 'oui', 'non', 3699.0, 'célibataire', 5.0, 0.57, '2023-11-12', 557.0, 661.31, 4247.479089404679)]

# %% [markdown]
# ### Remarques sur SQLAlchemy
#
# Les requetes se font via les fonction `select()`/`delete()`/`update()`/etc... ca génère une requete utilsé par `session.execute()` ou `session.scalars()`
#
# un print d'une des fonction `select()` et autres imprime la requetes SQL, voir si ca formate suivant le dialect SQL utilisé.
#
# On peux executer du SQL direct en utilisant `text()`

# %%
# Remplissage de pret
# liste_region = df['region'].unique()
# print(Region.__tablename__)
# session.execute(delete(Region))
# session.commit()

def fill_dictionnaire(field_or_keys, DataBase: Base):
    """
    Cette fonction permet de remplir un dictionnaire
    :param field_or_keys: Tableau de valeurs ou non de champ dans le dataframe
    :param DataBase: Classe de données à compléter
    :return:
    """
    # On commence par truncate la table
    if isinstance(field_or_keys, str):
        tableau = df[field_or_keys].unique()
    else:
        tableau = field_or_keys
    session.execute(delete(DataBase))
    for ligne in tableau:
        print(ligne)
        region = DataBase(**{'nom': ligne})
        session.add(region)

    # Ce coup ci on commit apres avoir ajouter tous les objet Region
    session.commit()


if populate_dico:
    fill_dictionnaire('region', Region)
    # Pour le niveau d'étude, on met les valeurs a la main pour accorder un "score" via l'ID (on peux faire autrement mais bon... on fait short)
    fill_dictionnaire(['aucun', 'bac', 'bac+2', 'master', 'doctorat'], Niveau_etude)

# %% [markdown]
# # Table Pret
#
# Maintenant on se charge de la table Pret.
#
# Principe :
# * On parcourt la table des clients
# * On cherche dans raw_data les lignes appartenant au client
# * On ajoute la ou les lignes de raw data dans le client, on compte sur SQLAlchemy pour faire le remplissage dans les bonnes tables.
# * On en profite pour mettre à jour les dictionnaires

# %%
populate_pret = True
if populate_pret:
    session.execute(delete(Pret))
    session.commit()

    liste_client = session.scalars(select(Client))
    for client in liste_client:
        # let's go
        print(f"Traitement client N°{client.id} ({client.prenom} {client.nom})")
        raw_data = session.scalars(select(Raw_data).where(sa.and_(
            Raw_data.nom == client.nom,
            Raw_data.prenom == client.prenom,
            Raw_data.sexe == client.sexe,
            Raw_data.nationalite_francaise == client.nationalite_francaise,
        ))).all()
        for raw in raw_data:
            # On met les données "brute"
            ligne_pret = Pret(
                age=raw.age,
                taille=raw.taille,
                poids=raw.poids,
                sport_licence=raw.sport_licence,
                smoker=raw.smoker,
                revenu_estime_mois=raw.revenu_estime_mois,
                situation_familiale=raw.situation_familiale,
                historique_credits=raw.historique_credits,
                risque_personnel=raw.risque_personnel,
                date_creation_compte=raw.date_creation_compte,
                score_credit=raw.score_credit,
                loyer_mensuel=raw.loyer_mensuel,
                montant_pret=raw.montant_pret
            )

            # On ajoute ligne_pret à la session pour qu'elle soit connu dans la suite du traitement.
            # Ca evite le warning décrit plus bas
            session.add(ligne_pret)

            # On ajoute maintenant les liaisons
            # Region
            region = session.scalars(select(Region).where(Region.nom == raw.region)).one()
            ligne_pret.region = region
            # Niveau Etude
            niveau_etude = session.scalars(select(Niveau_etude).where(Niveau_etude.nom == raw.niveau_etude)).one()
            ligne_pret.niveau_etude = niveau_etude

            # On ajoute maintenant la ligne de pret au client.
            client.prets.append(ligne_pret)


            print(region.__dict__)
            print(raw.age, raw.taille, raw.poids)

    session.commit()

        # print(type(raw_data))
        # print(raw_data)
# Out:
# Traitement client N°1 (Adam Abbott)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 74 165.2 57.1
# Traitement client N°2 (Pamela Acevedo)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 67 176.1 66.5
# Traitement client N°3 (Douglas Acosta)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 71 166.6 73.6
# Traitement client N°4 (Sarah Acosta)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 59 154.3 80.3
# Traitement client N°5 (Amy Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 56 177.9 63.9
# Traitement client N°6 (Brandi Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 24 186.3 62.2
# Traitement client N°7 (Casey Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 53 162.3 95.4
# Traitement client N°8 (Daniel Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 44 170.9 64.8
# Traitement client N°9 (Denise Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 23 171.8 53.9
# Traitement client N°10 (Elizabeth Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 75 171.6 85.3
# Traitement client N°11 (Heather Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 45 162.1 54.7
# Traitement client N°12 (Jeffrey Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 59 175.2 51.9
# Traitement client N°13 (Jennifer Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 19 182.6 60.0
# Traitement client N°14 (Joseph Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 38 182.3 69.7
# Traitement client N°15 (Kaitlyn Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 37 180.9 48.5
# Traitement client N°16 (Kimberly Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 71 187.3 69.4
# Traitement client N°17 (Miranda Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 58 177.8 64.0
# Traitement client N°18 (Ryan Adams)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 74 157.1 66.0
# Traitement client N°19 (Kathryn Adkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 75 165.6 80.2
# Traitement client N°20 (Mark Adkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 53 174.7 60.5
# Traitement client N°21 (William Adkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 48 167.3 54.8
# Traitement client N°22 (Craig Aguilar)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 58 159.4 57.0
# Traitement client N°23 (David Aguilar)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 62 188.9 57.2
# Traitement client N°24 (Jay Aguilar)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 53 170.0 103.2
# Traitement client N°25 (Jonathan Aguilar)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 63 162.1 74.9
# Traitement client N°26 (Nicole Aguilar)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 61 153.8 54.7
# Traitement client N°27 (Fred Aguirre)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 25 168.5 88.3
# Traitement client N°28 (Kathy Aguirre)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 48 154.6 52.5
# Traitement client N°29 (Kenneth Aguirre)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 54 179.2 84.6
# Traitement client N°30 (Michael Aguirre)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 43 175.5 61.8
# Traitement client N°31 (Christopher Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 22 170.8 60.9
# Traitement client N°32 (Isaac Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 38 170.6 80.1
# Traitement client N°33 (Kaitlyn Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 38 160.5 62.5
# Traitement client N°34 (Olivia Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 65 163.6 88.4
# Traitement client N°35 (Raymond Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 19 165.0 57.0
# Traitement client N°36 (Ryan Alexander)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 33 175.4 70.4
# Traitement client N°37 (Aaron Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 53 158.0 64.7
# Traitement client N°38 (Amanda Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 73 179.9 50.1
# Traitement client N°39 (Amber Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 20 170.4 62.7
# Traitement client N°40 (Andrew Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 62 163.3 87.7
# Traitement client N°41 (Anna Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 21 172.1 54.2
# Traitement client N°42 (Benjamin Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 47 183.6 35.806
# Traitement client N°43 (Carrie Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 56 180.2 72.9
# Traitement client N°44 (Christopher Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 59 174.8 67.4
# Traitement client N°45 (David Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 35 161.0 87.8
# Traitement client N°46 (Elizabeth Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 27 167.9 51.7
# Traitement client N°47 (Emily Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 28 178.7 47.1
# Traitement client N°48 (Jacob Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 54 152.6 94.4
# Traitement client N°49 (Jennifer Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 25 191.9 71.7
# Traitement client N°50 (Lynn Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 71 174.7 69.3
# Traitement client N°51 (Melvin Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 53 182.7 71.2
# Traitement client N°52 (Neil Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 32 163.8 67.8
# Traitement client N°53 (Stacey Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 40 179.1 80.2
# Traitement client N°54 (Wendy Allen)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 59 174.2 48.3
# Traitement client N°55 (Abigail Allison)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 21 159.1 80.6
# Traitement client N°56 (Jacqueline Allison)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 72 174.6 63.5
# Traitement client N°57 (Jacqueline Allison)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 33 168.5 44.2
# Traitement client N°58 (Derrick Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 30 160.5 65.5
# Traitement client N°59 (Kelly Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 70 171.0 89.6
# Traitement client N°60 (Martha Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 42 170.6 73.6
# Traitement client N°61 (Steven Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 64 184.8 77.7
# Traitement client N°62 (Tina Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 64 170.2 65.2
# Traitement client N°63 (William Alvarado)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 53 163.9 58.1
# Traitement client N°64 (Amy Alvarez)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 46 159.3 71.3
# Traitement client N°65 (Angela Alvarez)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 45 187.6 80.7
# Traitement client N°66 (Angelica Alvarez)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 37 173.8 71.2
# Traitement client N°67 (Anna Alvarez)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 35 179.6 75.4
# Traitement client N°68 (Samuel Alvarez)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 30 174.6 74.9
# Traitement client N°69 (Amy Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 47 168.0 35.806
# Traitement client N°70 (Ann Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 61 170.0 44.1
# Traitement client N°71 (Brandon Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 19 175.0 75.5
# Traitement client N°72 (Brent Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 50 172.1 70.5
# Traitement client N°73 (Brittany Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 53 172.2 77.0
# Traitement client N°74 (Bruce Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 64 168.8 87.6
# Traitement client N°75 (Carly Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 46 165.3 84.8
# Traitement client N°76 (Cassandra Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 65 160.9 58.3
# Traitement client N°77 (Craig Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 67 181.9 55.4
# Traitement client N°78 (Craig Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 50 175.4 68.6
# Traitement client N°79 (Crystal Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 22 160.1 75.1
# Traitement client N°80 (David Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 46 179.1 68.4
# Traitement client N°81 (Dawn Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 73 166.9 69.0
# Traitement client N°82 (Francisco Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 41 168.2 35.806
# Traitement client N°83 (Heather Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 34 168.2 71.7
# Traitement client N°84 (James Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 74 181.3 57.4
# Traitement client N°85 (James Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 39 152.6 83.9
# Traitement client N°86 (Jeffrey Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 61 168.9 72.7
# Traitement client N°87 (John Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 74 177.5 74.5
# Traitement client N°88 (Joseph Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 59 171.8 49.8
# Traitement client N°89 (Joshua Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 41 169.1 95.7
# Traitement client N°90 (Kelly Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 71 170.3 63.6
# Traitement client N°91 (Kenneth Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 72 185.0 97.3
# Traitement client N°92 (Laura Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 31 174.3 87.0
# Traitement client N°93 (Lauren Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 19 173.0 70.8
# Traitement client N°94 (Linda Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 40 173.9 75.3
# Traitement client N°95 (Lisa Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 26 174.6 90.5
# Traitement client N°96 (Meghan Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 67 146.9 89.1
# Traitement client N°97 (Raymond Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 55 172.4 96.0
# Traitement client N°98 (Robert Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 73 174.6 65.8
# Traitement client N°99 (Ronald Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 75 182.5 93.2
# Traitement client N°100 (Sabrina Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 69 166.8 66.4
# Traitement client N°101 (Tracy Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 43 157.8 57.7
# Traitement client N°102 (William Anderson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 66 184.8 72.2
# Traitement client N°103 (Elizabeth Andrade)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 43 188.9 101.1
# Traitement client N°104 (Richard Andrade)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 45 168.0 58.7
# Traitement client N°105 (Steve Andrade)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 57 168.6 70.7
# Traitement client N°106 (Jill Andrews)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 41 176.5 57.0
# Traitement client N°107 (Kelly Andrews)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 61 175.1 72.0
# Traitement client N°108 (Darryl Anthony)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 33 173.5 58.7
# Traitement client N°109 (Jessica Anthony)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 62 168.0 62.2
# Traitement client N°110 (Sharon Anthony)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 40 156.2 54.5
# Traitement client N°111 (Tiffany Anthony)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 65 162.3 86.9
# Traitement client N°112 (Travis Anthony)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 64 165.4 74.8
# Traitement client N°113 (Amanda Arias)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 39 156.8 70.8
# Traitement client N°114 (Katherine Arias)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 21 179.2 74.7
# Traitement client N°115 (Kimberly Arias)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 21 179.3 85.6
# Traitement client N°116 (Leslie Arias)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 29 172.7 90.2
# Traitement client N°117 (Danielle Armstrong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 35 178.7 103.2
# Traitement client N°118 (Elizabeth Armstrong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 28 176.9 99.3
# Traitement client N°119 (Anthony Arnold)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 51 178.3 53.5
# Traitement client N°120 (Antonio Arnold)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 53 164.7 79.1
# Traitement client N°121 (Deborah Arnold)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 39 169.8 35.806
# Traitement client N°122 (Logan Arnold)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 50 171.9 67.2
# Traitement client N°123 (Sandra Arnold)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 34 170.9 71.5
# Traitement client N°124 (Margaret Arroyo)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 36 184.5 75.5
# Traitement client N°125 (Dana Atkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 52 166.0 58.5
# Traitement client N°126 (Emily Atkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 65 186.1 83.3
# Traitement client N°127 (Sandra Atkins)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 57 179.2 83.5
# Traitement client N°128 (Chad Atkinson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 52 177.0 66.5
# Traitement client N°129 (Cheryl Austin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 63 173.2 86.6
# Traitement client N°130 (David Austin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 28 162.5 69.7
# Traitement client N°131 (Sarah Austin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 34 156.6 66.8
# Traitement client N°132 (Steven Austin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 21 189.6 75.6
# Traitement client N°133 (Tina Austin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 33 161.3 94.8
# Traitement client N°134 (Christopher Avery)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 22 158.2 61.5
# Traitement client N°135 (Jose Avery)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 57 172.5 50.8
# Traitement client N°136 (Olivia Avery)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 59 181.4 35.806
# Traitement client N°137 (Vickie Avery)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 43 162.0 102.1
# Traitement client N°138 (Matthew Avila)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 68 166.2 54.4
# Traitement client N°139 (Henry Ayala)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 71 165.5 78.6
# Traitement client N°140 (Melanie Ayala)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 57 158.6 35.806
# Traitement client N°141 (Peter Ayala)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 71 166.8 99.9
# Traitement client N°142 (Kara Ayers)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 47 172.5 68.3
# Traitement client N°143 (Alex Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 29 172.6 79.2
# Traitement client N°144 (Jacqueline Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 30 164.7 56.4
# Traitement client N°145 (Johnny Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 64 178.5 90.0
# Traitement client N°146 (Jordan Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 73 167.4 67.3
# Traitement client N°147 (Jorge Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 65 173.3 84.8
# Traitement client N°148 (Joshua Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 62 166.3 91.2
# Traitement client N°149 (Kelli Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 58 180.1 61.6
# Traitement client N°150 (Nicole Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 30 175.5 53.9
# Traitement client N°151 (Timothy Bailey)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 20 168.4 60.7
# Traitement client N°152 (Carol Baird)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 37 178.1 103.2
# Traitement client N°153 (Cory Baird)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 31 175.6 97.0
# Traitement client N°154 (Jose Baird)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 27 174.4 48.5
# Traitement client N°155 (Amy Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 66 178.8 90.4
# Traitement client N°156 (Andrew Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 24 177.0 35.806
# Traitement client N°157 (Audrey Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 40 160.2 83.4
# Traitement client N°158 (Barry Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 36 164.5 51.2
# Traitement client N°159 (Brandon Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 46 162.6 56.7
# Traitement client N°160 (Brian Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 51 160.3 61.3
# Traitement client N°161 (Daniel Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 59 164.5 61.4
# Traitement client N°162 (Denise Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 71 175.1 69.1
# Traitement client N°163 (Dwayne Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 46 151.0 39.0
# Traitement client N°164 (Eric Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 51 157.3 70.7
# Traitement client N°165 (James Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 29 157.3 78.9
# Traitement client N°166 (Jason Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 61 173.6 67.5
# Traitement client N°167 (Leslie Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 43 158.4 55.3
# Traitement client N°168 (Molly Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 37 169.6 83.2
# Traitement client N°169 (Rachel Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 67 180.2 61.0
# Traitement client N°170 (Roy Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 55 172.2 91.8
# Traitement client N°171 (Ryan Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 33 158.6 103.2
# Traitement client N°172 (Sara Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 65 190.0 56.2
# Traitement client N°173 (Shawn Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 32 164.6 78.0
# Traitement client N°174 (Yvonne Baker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 38 171.8 50.8
# Traitement client N°175 (Cynthia Baldwin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 70 162.7 77.9
# Traitement client N°176 (Hannah Baldwin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 63 180.7 75.4
# Traitement client N°177 (Kevin Baldwin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 60 168.9 60.9
# Traitement client N°178 (Aaron Ball)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 46 173.5 62.4
# Traitement client N°179 (Daniel Ball)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 41 181.5 52.3
# Traitement client N°180 (Lisa Ball)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 42 162.0 35.806
# Traitement client N°181 (Amy Ballard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 50 170.1 56.7
# Traitement client N°182 (Rebekah Ballard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 28 176.0 66.2
# Traitement client N°183 (Andre Banks)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 59 173.2 73.9
# Traitement client N°184 (Michael Banks)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 47 162.9 94.7
# Traitement client N°185 (Alexander Barajas)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 52 172.1 69.9
# Traitement client N°186 (Kimberly Barajas)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 45 180.1 64.3
# Traitement client N°187 (Bryan Barber)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 46 178.3 68.6
# Traitement client N°188 (Jodi Barber)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 34 163.0 81.6
# Traitement client N°189 (Darryl Barker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 73 160.5 70.3
# Traitement client N°190 (Mark Barker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 57 163.5 95.0
# Traitement client N°191 (Taylor Barker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 52 159.5 68.4
# Traitement client N°192 (Antonio Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 67 151.5 62.5
# Traitement client N°193 (Brittany Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 43 177.5 78.0
# Traitement client N°194 (Jonathan Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 39 175.3 58.5
# Traitement client N°195 (Lisa Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 48 151.0 52.5
# Traitement client N°196 (Matthew Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 50 169.3 70.0
# Traitement client N°197 (Michael Barnes)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 18 152.7 75.1
# Traitement client N°198 (Lydia Barnett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 22 164.1 45.9
# Traitement client N°199 (Sara Barnett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 58 184.9 72.7
# Traitement client N°200 (Crystal Barr)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 26 165.4 76.4
# Traitement client N°201 (Cynthia Barr)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 25 164.7 87.6
# Traitement client N°202 (Jessica Barr)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 49 162.8 81.8
# Traitement client N°203 (Jillian Barr)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 48 174.2 80.2
# Traitement client N°204 (Denise Barrera)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 50 178.0 78.9
# Traitement client N°205 (Julia Barrett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 51 169.9 72.2
# Traitement client N°206 (Matthew Barrett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 30 172.9 60.9
# Traitement client N°207 (Walter Barrett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 57 191.8 75.8
# Traitement client N°208 (Eric Barron)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 60 156.9 78.6
# Traitement client N°209 (Michael Barron)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 20 183.4 70.0
# Traitement client N°210 (John Barry)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 66 169.6 90.9
# Traitement client N°211 (Richard Barry)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 18 176.2 47.3
# Traitement client N°212 (Sharon Barry)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 31 174.0 67.8
# Traitement client N°213 (Susan Bartlett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 56 173.3 66.0
# Traitement client N°214 (Brandon Bass)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 44 162.3 45.4
# Traitement client N°215 (Jose Bass)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 27 176.1 63.7
# Traitement client N°216 (Samuel Bass)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 72 165.5 77.7
# Traitement client N°217 (Brenda Bates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 22 162.9 57.4
# Traitement client N°218 (Jacqueline Bates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 29 167.6 44.4
# Traitement client N°219 (Melissa Bates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 31 168.7 64.4
# Traitement client N°220 (Sandra Bates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 52 167.4 84.4
# Traitement client N°221 (Brenda Bauer)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 40 164.2 67.2
# Traitement client N°222 (Christopher Bauer)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 24 165.3 66.9
# Traitement client N°223 (Richard Bauer)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 33 167.3 98.5
# Traitement client N°224 (Charles Bautista)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 35 171.1 51.1
# Traitement client N°225 (James Bautista)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 50 161.4 40.7
# Traitement client N°226 (Lee Bautista)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 39 160.1 58.1
# Traitement client N°227 (Jennifer Bean)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 66 173.2 68.7
# Traitement client N°228 (Ryan Bean)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 29 184.2 69.4
# Traitement client N°229 (Susan Bean)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 72 175.0 71.8
# Traitement client N°230 (Joshua Beard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 68 185.4 56.5
# Traitement client N°231 (Lonnie Beard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 68 172.3 77.5
# Traitement client N°232 (Mary Beard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 31 160.8 58.4
# Traitement client N°233 (Timothy Beard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 60 168.9 59.8
# Traitement client N°234 (Jonathan Beasley)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 73 170.7 70.5
# Traitement client N°235 (Ronald Beck)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 54 180.3 75.4
# Traitement client N°236 (Mary Becker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 58 167.1 73.0
# Traitement client N°237 (Norma Becker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 32 167.1 76.5
# Traitement client N°238 (Pamela Becker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 51 174.0 73.5
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 41 164.2 76.6
# Traitement client N°239 (Robyn Becker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 56 165.2 93.0
# Traitement client N°240 (Shawn Becker)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 25 174.2 48.3
# Traitement client N°241 (Alejandra Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 19 170.9 75.9
# Traitement client N°242 (Amanda Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 62 174.5 87.5
# Traitement client N°243 (Cindy Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 18 176.4 74.6
# Traitement client N°244 (Cristina Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 73 168.4 78.5
# Traitement client N°245 (Gabriel Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 52 165.8 65.9
# Traitement client N°246 (Heather Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 25 146.9 49.5
# Traitement client N°247 (James Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 71 164.2 70.7
# Traitement client N°248 (Jennifer Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 53 158.6 72.2
# Traitement client N°249 (Kimberly Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 63 165.9 67.8
# Traitement client N°250 (Lindsey Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 61 156.1 66.6
# Traitement client N°251 (Nicole Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 61 160.9 48.5
# Traitement client N°252 (Pamela Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 61 166.0 77.7
# Traitement client N°253 (Richard Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 54 162.0 39.6
# Traitement client N°254 (Sean Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 36 166.0 91.5
# Traitement client N°255 (Stephanie Bell)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 40 154.4 75.8
# Traitement client N°256 (Aaron Bender)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 19 162.8 64.5
# Traitement client N°257 (Ronald Bender)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 23 170.4 57.2
# Traitement client N°258 (Anthony Benjamin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 50 180.8 85.5
# Traitement client N°259 (Dwayne Benjamin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 68 156.6 98.2
# Traitement client N°260 (Michelle Benjamin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 75 181.4 64.0
# Traitement client N°261 (Thomas Benjamin)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 63 165.0 77.1
# Traitement client N°262 (Alexis Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 73 170.7 76.3
# Traitement client N°263 (Alyssa Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 64 172.1 80.8
# Traitement client N°264 (Andrew Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 61 164.4 61.0
# Traitement client N°265 (Elijah Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 35 171.3 73.9
# Traitement client N°266 (Gabrielle Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 48 170.8 67.6
# Traitement client N°267 (Jason Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 29 169.2 67.1
# Traitement client N°268 (John Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 57 163.4 62.6
# Traitement client N°269 (Nicole Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 44 170.9 62.7
# Traitement client N°270 (Ruben Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 58 180.7 69.8
# Traitement client N°271 (Samantha Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 24 160.9 88.8
# Traitement client N°272 (Troy Bennett)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 56 165.4 66.3
# Traitement client N°273 (Hannah Benson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 20 184.3 76.6
# Traitement client N°274 (Jordan Benson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 44 171.9 61.6
# Traitement client N°275 (Olivia Benson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 63 175.1 73.1
# Traitement client N°276 (Richard Benson)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 45 168.7 84.5
# Traitement client N°277 (Peter Bentley)
# ...
# 43 187.7 67.6
# Traitement client N°4573 (James Wong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 61 157.2 68.2
# Traitement client N°4574 (Leslie Wong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 55 166.7 54.8
# Traitement client N°4575 (Michael Wong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 42 179.5 48.3
# Traitement client N°4576 (Natalie Wong)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 62 170.0 68.8
# Traitement client N°4577 (Alan Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 66 179.0 71.5
# Traitement client N°4578 (Cameron Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 32 177.6 47.3
# Traitement client N°4579 (Christopher Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 52 161.7 80.5
# Traitement client N°4580 (Eric Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 57 157.8 58.9
# Traitement client N°4581 (Joseph Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 36 173.6 65.8
# Traitement client N°4582 (Kaitlyn Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 67 185.9 55.8
# Traitement client N°4583 (Kathleen Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 48 174.1 64.1
# Traitement client N°4584 (Mary Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 49 155.3 36.9
# Traitement client N°4585 (Robert Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 70 173.1 96.6
# Traitement client N°4586 (Sarah Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 37 169.0 73.4
# Traitement client N°4587 (Steven Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 68 161.6 99.2
# Traitement client N°4588 (Thomas Wood)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 52 168.9 69.3
# Traitement client N°4589 (Kristina Woodard)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 39 181.2 95.4
# Traitement client N°4590 (Christopher Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 30 162.9 66.1
# Traitement client N°4591 (Dennis Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 59 166.3 79.3
# Traitement client N°4592 (Elijah Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 67 185.2 72.7
# Traitement client N°4593 (Kelly Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 44 161.7 84.1
# Traitement client N°4594 (Kevin Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 43 170.3 73.2
# Traitement client N°4595 (Lisa Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 18 173.0 81.9
# Traitement client N°4596 (Roy Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 34 166.0 38.5
# Traitement client N°4597 (Stacey Woods)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 46 163.5 72.2
# Traitement client N°4598 (Alexander Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 32 174.0 69.6
# Traitement client N°4599 (Bianca Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 24 165.9 57.7
# Traitement client N°4600 (Brandon Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 24 166.0 81.7
# Traitement client N°4601 (Cody Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 37 160.1 96.9
# Traitement client N°4602 (Daniel Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 32 170.7 98.3
# Traitement client N°4603 (David Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 32 167.1 50.5
# Traitement client N°4604 (Jacob Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 20 175.1 61.4
# Traitement client N°4605 (Jon Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 58 161.5 89.3
# Traitement client N°4606 (Justin Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 75 182.6 85.5
# Traitement client N°4607 (Kimberly Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 29 164.5 50.8
# Traitement client N°4608 (Leah Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 29 163.7 71.1
# Traitement client N°4609 (Michael Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 73 182.1 80.8
# Traitement client N°4610 (Michelle Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 40 171.6 44.8
# Traitement client N°4611 (Thomas Wright)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 34 170.7 58.4
# Traitement client N°4612 (Kevin Wu)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 27 164.9 45.0
# Traitement client N°4613 (Bridget Wyatt)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 21 160.1 56.1
# Traitement client N°4614 (Kevin Wyatt)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 59 172.9 65.0
# Traitement client N°4615 (Evan Yang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 23 189.9 71.8
# Traitement client N°4616 (Karen Yang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 19 189.7 61.1
# Traitement client N°4617 (William Yang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 48 163.5 65.2
# Traitement client N°4618 (Marvin Yates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 58 157.3 71.0
# Traitement client N°4619 (Morgan Yates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 41 179.8 66.9
# Traitement client N°4620 (Ronald Yates)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 44 170.1 50.1
# Traitement client N°4621 (Caleb Yoder)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 22 168.5 68.4
# Traitement client N°4622 (Erica Yoder)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 35 181.9 68.9
# Traitement client N°4623 (Mary Yoder)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 50 171.6 56.6
# Traitement client N°4624 (Debra York)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 73 185.2 53.3
# Traitement client N°4625 (Aaron Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 72 162.5 64.7
# Traitement client N°4626 (Austin Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 53 185.2 79.4
# Traitement client N°4627 (Brian Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 21 179.4 77.8
# Traitement client N°4628 (Claudia Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 65 187.1 88.0
# Traitement client N°4629 (Diane Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 51 169.7 86.7
# Traitement client N°4630 (Dustin Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 69 149.4 67.3
# Traitement client N°4631 (Edward Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 39 170.2 82.7
# Traitement client N°4632 (Eric Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 20 167.7 67.8
# Traitement client N°4633 (Frank Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 35 170.8 48.6
# Traitement client N°4634 (Jean Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 58 175.5 65.6
# Traitement client N°4635 (Jennifer Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 69 176.0 47.9
# Traitement client N°4636 (John Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 70 150.6 68.2
# Traitement client N°4637 (Jon Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 61 179.1 75.9
# Traitement client N°4638 (Katherine Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 67 169.6 82.1
# Traitement client N°4639 (Kevin Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 59 158.0 75.0
# Traitement client N°4640 (Kevin Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 32 175.6 86.5
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 43 174.6 64.9
# Traitement client N°4641 (Lauren Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 28 169.4 52.1
# Traitement client N°4642 (Lisa Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 24 169.1 68.1
# Traitement client N°4643 (Michael Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59f4d0>, 'nom': 'Occitanie', 'id': 6}
# 55 161.5 47.2
# Traitement client N°4644 (Monica Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 39 155.3 70.7
# Traitement client N°4645 (Priscilla Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 68 175.2 90.9
# Traitement client N°4646 (Steven Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 35 170.3 55.1
# Traitement client N°4647 (Theodore Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 25 170.8 70.6
# Traitement client N°4648 (Wesley Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 38 187.0 60.9
# Traitement client N°4649 (Whitney Young)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 74 174.0 65.8
# Traitement client N°4650 (Amanda Zamora)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 37 183.7 60.8
# Traitement client N°4651 (Austin Zamora)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 22 185.3 89.5
# Traitement client N°4652 (Jenna Zamora)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 25 157.4 55.4
# Traitement client N°4653 (Courtney Zavala)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 65 167.1 71.7
# Traitement client N°4654 (Anthony Zhang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e450>, 'nom': 'Auvergne-Rhône-Alpes', 'id': 2}
# 73 175.2 80.1
# Traitement client N°4655 (Matthew Zhang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 64 177.7 52.7
# Traitement client N°4656 (Melissa Zhang)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 55 179.3 59.6
# Traitement client N°4657 (Corey Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e7b0>, 'nom': 'Provence-Alpes-Côte d’Azur', 'id': 5}
# 33 170.6 74.1
# Traitement client N°4658 (Jared Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e150>, 'nom': 'Île-de-France', 'id': 1}
# 34 174.1 48.1
# Traitement client N°4659 (Kimberly Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59cad0>, 'nom': 'Hauts-de-France', 'id': 4}
# 40 160.8 84.2
# Traitement client N°4660 (Lisa Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e030>, 'nom': 'Corse', 'id': 8}
# 74 178.5 85.6
# Traitement client N°4661 (Mary Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59e570>, 'nom': 'Normandie', 'id': 7}
# 45 182.5 67.6
# Traitement client N°4662 (Michael Zimmerman)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 37 173.9 96.7
# Traitement client N°4663 (Mark Zuniga)
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7f50fe59df10>, 'nom': 'Bretagne', 'id': 3}
# 59 169.0 47.1

# %% [markdown]
# Voila les données sont importées
#
# Petite remarque : j'ai des warning lors de la création des contrats
#
# ```
# /tmp/ipykernel_15965/3707726440.py:38: SAWarning: Object of type <Pret> not in session, add operation along 'Region.prets' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   niveau_etude = session.scalars(select(Niveau_etude).where(Niveau_etude.nom == raw.niveau_etude)).one()
# /tmp/ipykernel_15965/3707726440.py:42: SAWarning: Object of type <Pret> not in session, add operation along 'Niveau_etude.prets' will not proceed (This warning originated from the Session 'autoflush' process, which was invoked automatically in response to a user-initiated operation. Consider using ``no_autoflush`` context manager if this warning happended while initializing objects.)
#   client.prets.append(ligne_pret)
# ```
#
# Il faudra voir pourquoi.

# %%
print(select(Client).where(sa.and_(Client.prenom == client.prenom, Client.nom == client.nom)))
print(sa.text("select * from client"))

result = session.execute(select(Client).limit(10)).all()
print(result)
for row in result:
    print(row)
    for item in row:
        print(item.nom)
# Out:
# SELECT client.id, client.nom, client.prenom, client.sexe, client.nationalite_francaise
# FROM client
# WHERE client.prenom = :prenom_1 AND client.nom = :nom_1
# select * from client
# [(<__main__.Client object at 0x7f50fe954dd0>,), (<__main__.Client object at 0x7f50fe943950>,), (<__main__.Client object at 0x7f50fe940aa0>,), (<__main__.Client object at 0x7f50fe955730>,), (<__main__.Client object at 0x7f50fe956510>,), (<__main__.Client object at 0x7f50fe956240>,), (<__main__.Client object at 0x7f50fe9548f0>,), (<__main__.Client object at 0x7f50fe954ce0>,), (<__main__.Client object at 0x7f50fdc82900>,), (<__main__.Client object at 0x7f50fe967560>,)]
# (<__main__.Client object at 0x7f50fe954dd0>,)
# Abbott
# (<__main__.Client object at 0x7f50fe943950>,)
# Acevedo
# (<__main__.Client object at 0x7f50fe940aa0>,)
# Acosta
# (<__main__.Client object at 0x7f50fe955730>,)
# Acosta
# (<__main__.Client object at 0x7f50fe956510>,)
# Adams
# (<__main__.Client object at 0x7f50fe956240>,)
# Adams
# (<__main__.Client object at 0x7f50fe9548f0>,)
# Adams
# (<__main__.Client object at 0x7f50fe954ce0>,)
# Adams
# (<__main__.Client object at 0x7f50fdc82900>,)
# Adams
# (<__main__.Client object at 0x7f50fe967560>,)
# Adams
